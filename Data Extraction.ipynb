# %%
import pickle
import pandas as pd
import numpy as np
import os

pd.set_option('display.max_colwidth', 100)

# %%
from lxml import etree
from tqdm.notebook import tqdm
import os

def extract_info(xml_string, filename):
    root = etree.fromstring(xml_string)

    bibl_structs = root.findall(".//{*}biblStruct")
    information_list = []

    for bibl_struct in bibl_structs:
        information = {'Original Filename': filename[:-7] + 'pdf'}
        paper_title = bibl_struct.find(".//{*}title[@level='a']")
        paper_title = paper_title.text if paper_title is not None else ''
        information['Title'] = paper_title
    
        authors = bibl_struct.findall(".//{*}author/{*}persName")
        author_names = []
        for author in authors:
            first_name = author.find("{*}forename[@type='first']")
            last_name = author.find("{*}surname")

            first_name = first_name.text if first_name is not None else ''
            last_name = last_name.text if last_name is not None else ''

            author_names.append(f"{first_name} {last_name}")
        information['Authors'] = author_names

        publication_venue = bibl_struct.find(".//{*}title[@level='j']")
        if publication_venue is not None:
            information['Publication Venue'] = publication_venue.text
        else:
            publication_venue = bibl_struct.find(".//{*}title[@level='m']")
            if publication_venue is not None:
                information['Publication Venue'] = publication_venue.text

        if len(information['Authors']) and 'Publication Venue' in information:
            information_list.append(information)

    return information_list

base_dir = './dataset/GROBID-output/references'
citations = []

for filename in tqdm(os.listdir(base_dir)):
    if filename.endswith('.xml'):
        with open(os.path.join(base_dir, filename), 'rb') as file:
            info = extract_info(file.read(), filename)
            citations.extend(info)

citations_df = pd.DataFrame(citations)
# Out:
#   0%|          | 0/10027 [00:00<?, ?it/s]

# %%
citations_df
# Out:
#        Original Filename  \
# 0          0704.0213.pdf
# 1          0704.0213.pdf
# 2          0704.0213.pdf
# 3          0704.0213.pdf
# 4          0704.0213.pdf
# ...                  ...
# 338458    2112.04902.pdf
# 338459    2112.04902.pdf
# 338460    2112.04902.pdf
# 338461    2112.04902.pdf
# 338462    2112.04902.pdf
#
#                                                                                                       Title  \
# 0                                     Tensor product multiplicities and convex polytopes in partition space
# 1                                 On the computation of Clebsch-Gordan coefficients and the dilation effect
# 2               Polynomial algorithms for computing the Smith and Hermite normal forms of an integer matrix
# 3                                                    A new polynomial-time algorithm for linear programming
# 4                                                             A polynomial algorithm for linear programming
# ...                                                                                                     ...
# 338458
# 338459                                                Real-time fmri neurofeedback: progress and challenges
# 338460
# 338461             Conn: a functional connectivity toolbox for correlated and anticorrelated brain networks
# 338462  Discriminating schizophrenia using recurrent neural network applied on time courses of multi-sit...
#
#                                                                                                     Authors  \
# 0                                                                              [A Berenstein, A Zelevinsky]
# 1                                                                                   [J Loera, T Mcallister]
# 2                                                                                      [R Kannan, A Bachem]
# 3                                                                                             [N Karmarkar]
# 4                                                                                              [L Khachian]
# ...                                                                                                     ...
# 338458                                                                           [C Spielberger, R Gorsuch]
# 338459  [J Sulzer, S Haller, F Scharnowski, N Weiskopf, N Birbaumer, M Blefari, A Bruehl, L Cohen, R Dec...
# 338460                                        [F Weathers, D Blake, P Schnurr, D Kaloupek, B Marx, T Keane]
# 338461                                                             [S Whitfield-Gabrieli, A Nieto-Castanon]
# 338462                          [W Yan, V Calhoun, M Song, Y Cui, H Yan, S Liu, L Fan, N Zuo, Z Yang, K Xu]
#
#                                                                                         Publication Venue
# 0                                                                                           J. Geom. Phys
# 1                                                                                        Experiment. Math
# 2                                                                                          SIAM J. Comput
# 3                                                                                           Combinatorica
# 4                                                                              Doklady Akedamii Nauk SSSR
# ...                                                                                                   ...
# 338458  State-trait anxiety inventory for adults: Manual and sample: Manual, instrument and scoring guide
# 338459                                                                                         Neuroimage
# 338460                                           The clinician-administered ptsd scale for dsm-5 (caps-5)
# 338461                                                                                 Brain connectivity
# 338462                                                                                       EBioMedicine
#
# [338463 rows x 4 columns]

# %%
import pickle

with open("citations_df.pkl", 'wb') as file:
    pickle.dump(citations_df, file, protocol=pickle.HIGHEST_PROTOCOL)
